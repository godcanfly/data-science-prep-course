# %% [markdown]
# # 模块0｜环境配置与健康AI入门
#
# **目标**：配置 Gemini API，理解AI如何帮助我们分析健康数据
#
# ---
#
# ## 欢迎来到AI健康体检官工作坊！
#
# 在这个模块中，我们将：
# 1. ✅ 配置开发环境（Gemini API）
# 2. ✅ 测试AI连接
# 3. ✅ 了解健康数据的基本概念
# 4. ✅ 让AI进行第一次健康数据分析
#
# ---
#
# ## 重要提醒
#
# ⚠️ **数据安全提示**：使用Gemini API时，你输入的数据会发送到Google服务器。
#
# ⚠️ **医疗免责**：AI建议仅供参考，不能替代专业医疗诊断
#
# ---

# %% [markdown]
# ## 步骤1：安装必要的库

# %%
# 安装 Google Generative AI 库（用于调用 Gemini API）
# %pip install -q google-genai

print("✅ 库安装完成！")
# Out:
# ✅ 库安装完成！

# %% [markdown]
# ## 步骤2：配置 Gemini API Key
#
# ### 如何获取API Key：
#
# 1. 访问：https://makersuite.google.com/app/apikey
# 2. 登录你的Google账号
# 3. 点击「Create API key」
# 4. 复制生成的API Key
#
# ### 在Colab中保存API Key：
#
# 1. 点击左侧的🔑图标（Secrets）
# 2. 添加一个新的secret，名称为：`GEMINI_API_KEY`
# 3. 粘贴你的API Key
# 4. 打开「Notebook access」开关
#
# ---

# %%
import os
from google import genai
from google.genai import types

# 如果在 Colab 中运行
try:
    from google.colab import userdata
    api_key = userdata.get('GEMINI_API_KEY')
except ImportError:
    # 如果在本地运行，从环境变量读取
    api_key = os.getenv('GEMINI_API_KEY')

if not api_key:
    raise ValueError("❌ 请先配置 GEMINI_API_KEY")

client = genai.Client(api_key=api_key)
print("✅ Gemini API 配置成功！")
# Out:
# ✅ Gemini API 配置成功！

# %% [markdown]
# ## 步骤3：测试 Gemini 连接

# %%
# 测试：让AI鼓励你开始健康管理
response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents="请用一句话鼓励想要改善健康习惯的人！"
)

print("🤖 AI说：")
print(response.text)
# Out:
# 🤖 AI说：
# 为了更美好的自己，现在就是最好的开始！

# %% [markdown]
# ## 步骤4：理解健康数据的四大维度
#
# 在AI健康管理中，我们主要关注四个方面：
#
# ### 🍎 1. 营养（Nutrition）
# - **关键指标**：热量摄入、营养均衡度、三餐规律性
# - **数据来源**：饮食日记、食物照片、热量记录
# - **AI能做什么**：识别食物、计算营养、评估饮食健康度
#
# ### 😴 2. 睡眠（Sleep）
# - **关键指标**：睡眠时长、入睡时间、睡眠质量评分
# - **数据来源**：睡眠手环、主观记录、作息日志
# - **AI能做什么**：分析睡眠模式、识别睡眠问题、提供改善建议
#
# ### 🏃 3. 运动（Exercise）
# - **关键指标**：步数、运动时长、运动类型、心率
# - **数据来源**：计步器、运动App、健身记录
# - **AI能做什么**：追踪运动习惯、建议运动计划、评估运动强度
#
# ### 😌 4. 压力（Stress）
# - **关键指标**：情绪评分、压力水平、工作强度
# - **数据来源**：心情日记、压力自评、工作时长
# - **AI能做什么**：识别压力模式、提供减压建议、预警健康风险
#
# ---

# %% [markdown]
# ## 步骤5：第一次健康数据分析
#
# 让我们用AI分析一段简单的健康记录

# %%
# 示例：一天的健康记录
health_diary = """
今天早上7点起床，感觉有点累。
早餐吃了煎饼果子和豆浆。
上午工作比较忙，一直坐着，几乎没起来活动。
中午吃了公司食堂的盖浇饭，有点油腻。
下午开会压力很大，喝了3杯咖啡。
晚上加班到9点，叫了外卖麻辣烫。
回家后刷手机到凌晨1点才睡。
"""

# 让AI分析这段记录并给出评价
prompt = f"""
请分析以下健康记录，从营养、睡眠、运动、压力四个维度给出评价和改善建议：

{health_diary}

请用清晰的结构输出：
1. 各维度评分（0-100分）
2. 主要问题
3. 最容易实施的3条改善建议
"""

response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents=prompt
)
print("🏥 AI健康分析：")
print(response.text)
# Out:
# 🏥 AI健康分析：
# 好的，根据您的健康记录，以下是从营养、睡眠、运动、压力四个维度的评价和改善建议：
#
# ---
#
# ### 健康记录分析报告
#
# **1. 各维度评分 (0-100分)**
#
# *   **营养：30/100分**
#     *   早餐煎饼果子和豆浆，煎饼果子通常高碳水高油，豆浆较好。
#     *   午餐盖浇饭油腻，可能缺乏蔬菜和优质蛋白质。
#     *   晚餐麻辣烫外卖，容易高油、高盐、重口味，食材选择也可能不均衡。
#     *   全天缺乏新鲜蔬菜水果、全谷物、优质蛋白的摄入，过度依赖外卖和加工食品，并摄入过多咖啡。
# *   **睡眠：10/100分**
#     *   从凌晨1点睡到早上7点，睡眠时长仅6小时，远低于成人推荐的7-9小时。
#     *   醒来感觉累，表明睡眠质量差。
#     *   睡前刷手机到凌晨1点，严重影响入睡和睡眠质量。
# *   **运动：5/100分**
#     *   上午“一直坐着，几乎没起来活动”，全天没有提及任何形式的运动或规律的身体活动。
#     *   生活方式极端久坐，对身体健康有显著负面影响。
# *   **压力：20/100分**
#     *   早上起床感觉累，表明身体已处于疲劳状态。
#     *   工作忙碌、会议压力大、加班，都是明确的压力源。
#     *   喝3杯咖啡应对压力和疲劳，是一种短期提神但可能加剧焦虑和影响睡眠的策略。
#     *   睡前刷手机到凌晨，可能是疲劳和压力的一个表现或逃避方式，但进一步恶化了睡眠。
#
# ---
#
# **2. 主要问题**
#
# *   **营养不均衡：** 饮食结构高油、高盐、高碳水、加工食品多，缺乏膳食纤维、维生素和矿物质。
# *   **严重睡眠不足：** 睡眠时间过短，质量极差，并有不良睡前习惯（刷手机）。
# *   **极端久坐：** 全天几乎没有身体活动，缺乏必要的运动量。
# *   **高压且应对不良：** 工作压力大，但缺乏有效的减压和放松机制，反而通过咖啡和熬夜刷手机来应对，形成恶性循环。
#
# ---
#
# **3. 最容易实施的3条改善建议**
#
# 1.  **设立“睡前一小时无屏幕”规则：** 从今晚开始，尝试在睡前至少30-60分钟停止使用手机、平板或电脑。可以改为阅读纸质书、听轻音乐、做简单的伸展运动或冥想，帮助大脑放松，更容易入睡，改善睡眠质量。
# 2.  **每小时起身活动2-5分钟：** 在工作期间设置闹钟提醒，每隔一小时就起身，活动一下身体。可以站起来接水、去洗手间、走动几步、伸展一下胳膊和腿，打断久坐状态。
# 3.  **午餐增加一份蔬菜：** 尝试在公司食堂点餐时，额外选择一份清炒蔬菜或凉拌菜，或者自备一个水果，以增加膳食纤维和维生素的摄入，改善午餐盖浇饭的营养结构。

# %% [markdown]
# ## 步骤6：尝试分析你自己的一天
#
# 现在轮到你了！回忆一下你昨天的健康状况，让AI帮你分析。

# %%
# 在这里输入你自己的健康记录
my_health_diary = """
请在这里描述你昨天的：
- 起床和睡觉时间
- 三餐吃了什么
- 运动情况（步数、锻炼等）
- 工作/学习压力
- 整体感受

（如果不想分享真实数据，可以保持示例数据）
"""

# AI分析
prompt = f"""
请分析以下健康记录，从营养、睡眠、运动、压力四个维度给出评分和具体建议：

{my_health_diary}
"""

response = client.models.generate_content(
    model='gemini-2.5-pro',
    contents=prompt
)
print("🏥 你的健康分析：")
print(response.text)
# Out:
# 🏥 你的健康分析：
# 好的，这是一个非常棒的自我审视和健康管理的习惯！
#
# 请将您昨天的记录填写在下方，我会为您提供一份详尽的分析报告。
#
# ---
#
# **请在这里填写您昨天的记录：**
#
# *   **起床和睡觉时间：**
#     *   起床时间：[例如：早上 7:30]
#     *   睡觉时间：[例如：晚上 12:30]
# *   **三餐吃了什么：**
#     *   早餐：[例如：一杯黑咖啡，一个便利店的面包]
#     *   午餐：[例如：外卖的麻辣香锅，一碗米饭]
#     *   晚餐：[例如：鸡胸肉蔬菜沙拉]
#     *   其他加餐：[例如：下午吃了一包薯片]
# *   **运动情况：**
#     *   步数：[例如：5000步]
#     *   锻炼：[例如：无]
# *   **工作/学习压力：**
#     *   [例如：压力很大，有一个重要的项目截止日期临近]
# *   **整体感受：**
#     *   [例如：感觉很疲惫，有点焦虑，晚上精力不济]
#
# ---
#
# **在您填写后，我会根据您的具体情况给出分析。**
#
# 为了让您了解分析的框架和维度，我将先使用上述**示例数据**进行一次完整的分析演示。
#
# ### **健康记录分析报告 (基于示例数据)**
#
# #### **综合评估**
#
# 整体来看，您在有意识地关注自己的健康状况，尤其在晚餐的选择上体现了健康意识，这是非常棒的起点。目前主要的挑战在于**营养均衡性、运动量和压力管理**。通过一些小调整，可以显著提升整体的精力水平和幸福感。
#
# ---
#
# ### **四大维度评分与建议**
#
# #### **1. 营养 (Nutrition)**
#
# *   **评分：5/10 分**
# *   **优点：**
#     *   晚餐的选择（鸡胸肉蔬菜沙拉）非常健康，补充了优质蛋白质和膳食纤维。
# *   **可改进之处：**
#     *   **早餐过于简单**：缺乏足够的蛋白质和营养，可能导致上午精力不足和血糖波动。
#     *   **午餐油盐过重**：外卖的麻辣香锅通常高油、高盐、高热量，长期如此对心血管和消化系统有负担。
#     *   **缺乏水果和优质脂肪**：全天没有摄入水果，缺少来自坚果、牛油果等的健康脂肪。
#     *   **零食选择不佳**：薯片是高热量、低营养的零食，容易导致下午犯困和热量超标。
# *   **具体建议：**
#     1.  **优化早餐**：在现有基础上**加一个鸡蛋或一杯牛奶/豆浆**，将面包换成全麦面包，能提供更持久的能量。
#     2.  **改善午餐**：如果点外卖，尽量选择**蒸、煮、或少油烹饪的菜品**，如轻食套餐、日式定食等。有条件自己带饭是最佳选择。
#     3.  **健康零食替换**：将薯片换成**一小把坚果、一个水果、一杯酸奶或一根黄瓜**，既能解馋，又能补充营养。
#     4.  **保证饮水**：确保每天饮用1.5-2升水，而不是只靠咖啡。
#
# #### **2. 睡眠 (Sleep)**
#
# *   **评分：7/10 分**
# *   **优点：**
#     *   睡眠时长达到7小时，基本满足成年人的最低需求。
# *   **可改进之处：**
#     *   **入睡时间偏晚**：凌晨后入睡可能会影响深度睡眠质量和身体的修复节律，导致醒来后依然感觉疲惫。
# *   **具体建议：**
#     1.  **逐步提前入睡时间**：尝试每天提前15分钟上床，目标是稳定在**晚上11:30之前**入睡。
#     2.  **建立睡前仪式**：睡前1小时关闭手机、电脑等电子设备，可以改为看书、听轻音乐、热水泡脚或进行简单的拉伸，帮助身体和大脑放松。
#     3.  **避免睡前摄入咖啡因**：下午3点后尽量避免饮用咖啡或浓茶。
#
# #### **3. 运动 (Exercise)**
#
# *   **评分：4/10 分**
# *   **优点：**
#     *   有基础的日常活动步数，避免了久坐不动。
# *   **可改进之处：**
#     *   **活动量不足**：5000步低于世界卫生组织推荐的每日健康步数（约8000-10000步）。
#     *   **缺乏中高强度锻炼**：没有专门的心肺功能或力量训练，对心血管健康和肌肉维持益处有限。
# *   **具体建议：**
#     1.  **“碎片化”增加步数**：可以**午休时散步15分钟**，或者上下班提前一站下车步行，轻松增加2000-3000步。
#     2.  **安排微型锻炼**：每周安排**2-3次**，每次**20-30分钟**的锻炼。可以是快走、慢跑、跳绳，或是在家跟着App做一些简单的力量训练。
#     3.  **利用工作间隙**：每工作1小时，站起来活动5分钟，做一些简单的伸展，可以有效缓解身体僵硬。
#
# #### **4. 压力 (Stress)**
#
# *   **评分：3/10 分**
# *   **优点：**
#     *   能够清晰地意识到自己正处于压力之下，这是有效管理的第一步。
# *   **可改进之处：**
#     *   **压力影响了整体感受**：“疲惫”和“焦虑”是典型的压力反应，表明当前的压力水平已经对身心造成了负面影响。
#     *   **缺乏有效的应对机制**：从记录来看，当天没有采取主动的压力缓解措施。
# *   **具体建议：**
#     1.  **正念呼吸练习**：当感到焦虑时，暂停手中的事情，进行**5分钟的深呼吸练习**（吸气4秒，屏住4秒，呼气6秒），能快速平静神经系统。
#     2.  **划分工作与生活界限**：下班后有意识地“断开”工作，从事一些能让自己放松的爱好，如听音乐、看电影、与朋友聊天。
#     3.  **将运动作为解压方式**：即使是15分钟的快走，也能有效释放压力荷尔蒙，提升情绪。
#     4.  **任务分解**：面对项目截止日期，将大任务分解成多个可执行的小步骤，每完成一步就给自己一点积极反馈，可以减轻压迫感。
#
# **期待您提供真实数据，我将为您量身定制一份更具针对性的分析和建议！**

# %% [markdown]
# ## 🎉 恭喜！模块0完成
#
# ### 你已经学会了：
# - ✅ 配置Gemini API
# - ✅ 调用AI模型
# - ✅ 理解健康数据的四大维度
# - ✅ 使用AI进行基础健康分析
#
# ### 接下来：
# 在**模块1**中，我们将学习如何让AI更精确地解析结构化健康数据，提取营养信息、睡眠数据等。
#
# ---
#
# ## 💡 思考题
#
# 1. AI给出的建议中，哪一条你觉得最实用？
# 2. 你认为AI健康分析的局限性是什么？
# 3. 除了四大维度，你还想追踪哪些健康指标？
#
# ---
#
# **准备好了吗？让我们进入模块1！** 🚀
