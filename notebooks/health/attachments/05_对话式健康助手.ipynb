# %% [markdown]
# # 模块5｜多轮对话与上下文管理 - 个性化健康顾问
#
# **注意**：本文件原为 04，现在对应新课程结构的模块5
#
# **核心技术**：Chat Session与上下文管理
#
# **目标**：构建能"记住"对话历史的AI健康助手，提供连贯的个性化建议
#
# ---
#
# ## 本模块学习目标
#
# 在这个模块中，我们将：
# 1. ✅ 理解Chat Session的作用
# 2. ✅ 使用`model.start_chat()`创建对话
# 3. ✅ 维护和利用对话历史
# 4. ✅ 实现多轮连续对话
# 5. ✅ 提供基于上下文的个性化建议
#
# ---
#
# ## 为什么需要对话上下文？
#
# ### 没有上下文的问题：
#
# ```
# 用户：我最近总失眠
# AI：建议早睡早起，保持规律作息
#
# 用户：具体几点睡比较好？
# AI：一般建议10-11点睡 ❌ (AI忘记了用户有失眠问题)
# ```
#
# ###有上下文的优势：
#
# ```
# 用户：我最近总失眠
# AI：了解了。你通常几点上床？[记住：用户失眠]
#
# 用户：12点左右
# AI：[记住：失眠 + 12点睡] 入睡需要多久？
#
# 用户：至少1小时
# AI：[记住：失眠 + 12点上床 + 1小时入睡]
#    看来是入睡困难。白天有什么压力吗？
#
# 用户：工作压力挺大的
# AI：[结合所有上下文] 看来是压力导致的入睡困难。
#    建议：睡前1小时放下手机，尝试冥想...
# ```
#
# ---
#
# ---

# %% [markdown]
# ## 1️⃣ 环境配置

# %%
# 安装依赖
# %pip install -q google-genai

# %%
import os
from google import genai
from google.genai import types

# 如果在 Colab 中运行
try:
    from google.colab import userdata
    api_key = userdata.get('GEMINI_API_KEY')
except ImportError:
    # 如果在本地运行，从环境变量读取
    api_key = os.getenv('GEMINI_API_KEY')

if not api_key:
    raise ValueError("❌ 请先配置 GEMINI_API_KEY")

client = genai.Client(api_key=api_key)
print("✅ Gemini API 配置成功！")
# Out:
# ✅ Gemini API 配置成功！

# %% [markdown]
# ## 2️⃣ 对比：无上下文 vs 有上下文
#
# 先看看没有上下文管理时会发生什么

# %%
# 第一轮对话（无状态）
response1 = client.models.generate_content(
    model='gemini-2.5-pro',
    contents="我最近总失眠，怎么办？简短的回答"
)
print("👤 用户：我最近总失眠，怎么办？简短的回答")
print(f"🤖 AI：{response1.text}\n")
print("="*50 + "\n")

# 第二轮对话（AI不记得第一轮）
response2 = client.models.generate_content(
    model='gemini-2.5-pro',
    contents="那我应该几点睡？简短的回答"
)
print("👤 用户：那我应该几点睡？简短的回答")
print(f"🤖 AI：{response2.text}\n")

print("❌ 问题：AI不记得用户有失眠问题，给出了通用建议")
# Out:
# 👤 用户：我最近总失眠，怎么办？简短的回答
# 🤖 AI：失眠很困扰，可以试试以下方法：
#
# 1.  **规律作息**：每天定时睡觉和起床，即使是周末。
# 2.  **改善环境**：保持卧室黑暗、安静、凉爽。
# 3.  **睡前放松**：睡前1小时远离手机和电脑，可以洗个热水澡、听些轻音乐或进行深呼吸。
# 4.  **注意饮食**：下午和晚上避免摄入咖啡因（咖啡、茶、可乐），睡前不大量进食或饮酒。
# 5.  **白天运动**：白天进行适度运动，但避免在睡前3小时内剧烈运动。
#
# **如果持续不见好转，严重影响生活，建议及时咨询医生。**
#
# ==================================================
#
# 👤 用户：那我应该几点睡？简短的回答
# 🤖 AI：**从你的起床时间往前推算7.5或9个小时。**
#
# 例如，如果你早上7点起床，可以试试晚上10点或11点半睡觉。这样可以保证你完成5或6个完整的睡眠周期。
#
# ❌ 问题：AI不记得用户有失眠问题，给出了通用建议

# %% [markdown]
# ## 3️⃣ 使用Chat Session管理上下文
#
# 使用`model.start_chat()`创建带有历史记录的对话

# %%
# 创建Chat Session（使用空历史）
chat_history = [
    types.Content(role='user', parts=[types.Part(text="简单清晰的回答用户问题")]) # 初始 prompt
]

print("✅ Chat Session已创建")
print(f"   历史消息数：{len(chat_history)}")
# Out:
# ✅ Chat Session已创建
#    历史消息数：1

# %% [markdown]
# ## 4️⃣ 示例1：多轮失眠咨询对话
#
# AI会记住之前的对话，提供连贯的建议

# %%
# 辅助函数：发送消息并更新历史
def send_message(message, history):
    # 添加用户消息到历史
    history.append(
        types.Content(role='user', parts=[types.Part(text=message)]))

    print(history)
    # 调用API
    response = client.models.generate_content(
        model='gemini-2.5-pro',
        contents=history
    )

    # 添加AI响应到历史
    history.append(types.Content(role='model', parts=[types.Part(text=response.text)]))

    return response

# 第1轮对话
print("【第1轮对话】")
response = send_message("我最近总失眠，怎么办？", chat_history)
print("👤 用户：我最近总失眠，怎么办？")
print(f"🤖 AI：{response.text}\n")
print("="*50 + "\n")

# 第2轮对话
print("【第2轮对话】")
response = send_message("我通常12点左右上床", chat_history)
print("👤 用户：我通常12点左右上床")
print(f"🤖 AI：{response.text}\n")
print("="*50 + "\n")

# 第3轮对话
print("【第3轮对话】")
response = send_message("入睡需要至少1小时", chat_history)
print("👤 用户：入睡需要至少1小时")
print(f"🤖 AI：{response.text}\n")
print("="*50 + "\n")

# 第4轮对话
print("【第4轮对话】")
response = send_message("工作压力确实挺大的", chat_history)
print("👤 用户：工作压力确实挺大的")
print(f"🤖 AI：{response.text}\n")
print("="*50 + "\n")

# 第5轮对话
print("【第5轮对话】")
response = send_message("有什么具体的改善建议吗？", chat_history)
print("👤 用户：有什么具体的改善建议吗？")
print(f"🤖 AI：{response.text}\n")

print("✅ AI记住了所有信息：")
print("   - 失眠问题")
print("   - 12点上床")
print("   - 入睡需要1小时")
print("   - 工作压力大")
print("   - 给出了针对性的建议")
# Out:
# 【第1轮对话】
# [Content(
#   parts=[
#     Part(
#       text='简单清晰的回答用户问题'
#     ),
#   ],
#   role='user'
# ), Content(
#   parts=[
#     Part(
#       text='我最近总失眠，怎么办？'
#     ),
#   ],
#   role='user'
# )]
# 👤 用户：我最近总失眠，怎么办？
# 🤖 AI：好的，非常理解你被失眠困扰的感受。失眠确实很痛苦。
#
# 这里为你整理了一些简单清晰、可以立刻开始尝试的方法，希望能帮到你。
#
# 你可以把这些方法看作一个“睡眠工具箱”，尝试几种，找到最适合你的组合。
#
# ### 一、 睡前准备（营造睡觉的“仪式感”）
#
# 1.  **放松身体**：睡前1-2小时，洗个热水澡、泡个脚，或者用温毛巾热敷一下眼睛和脖子，让身体暖和放松下来。
# 2.  **远离电子产品**：至少在睡前1小时，放下手机、电脑、电视。屏幕的蓝光会抑制褪黑素（帮助你入睡的激素）的分泌。可以改成看会儿纸质书、听听舒缓的音乐或播客。
# 3.  **创造舒适环境**：把卧室弄得**暗一点、安静一点、凉快一点**。可以使用遮光窗帘、耳塞或白噪音机。
# 4.  **别在床上干别的事**：床只用来睡觉和亲密行为。不要在床上工作、玩手机或吃饭，让你的大脑把“床”和“睡觉”牢牢绑定在一起。
#
# ### 二、 白天习惯（调整你的生物钟）
#
# 1.  **作息规律**：每天尽量在**同一时间睡觉，同一时间起床**，即使是周末也要坚持。这是最有效的方法之一。
# 2.  **白天多晒太阳**：早上起床后，拉开窗帘，晒15-30分钟太阳。这能帮你校准生物钟，让身体知道“现在是白天，该清醒了”。
# 3.  **规律运动**：白天进行适度的运动（比如散步、慢跑、瑜伽）非常有帮助，但**不要在睡前3小时内剧烈运动**，否则会让身体太兴奋。
# 4.  **注意饮食**：
#     *   **避免咖啡因和酒精**：下午之后尽量不喝咖啡、浓茶、可乐等含咖啡因的饮料。酒精虽然能让你很快睡着，但会严重破坏后半夜的睡眠质量。
#     *   **睡前别吃太饱或太饿**：晚餐别吃太晚。如果睡前饿了，可以喝一小杯温牛奶或吃一根香蕉。
#
# ### 三、 心态调整（别跟“睡不着”这件事较劲）
#
# 1.  **放下“必须睡着”的压力**：越是强迫自己入睡，就越焦虑，越睡不着。告诉自己，躺着休息也是好的。
# 2.  **如果睡不着就起来**：如果在床上躺了20-30分钟还是毫无睡意，不要干躺着。**起床**，去另一个房间做点放松的事（比如看看书、听听音乐），直到感觉困了再回到床上。
# 3.  **把烦恼写下来**：如果脑子里总是有各种烦心事，可以在睡前花10分钟，把它们写在一个本子上。这就像把烦恼“清空”出大脑，有助于平静下来。
#
# ---
#
# ### **重要提醒：什么时候该去看医生？**
#
# 如果出现以下情况，建议尽快咨询医生（可以去医院的**睡眠科**或**神经内科**）：
#
# *   **失眠持续超过一个月**，并且尝试了以上方法后没有改善。
# *   失眠已经**严重影响了你的日常生活、工作和情绪**（比如白天非常疲惫、注意力不集中、容易发脾气）。
# *   失眠的同时，还伴有**情绪低落、焦虑、呼吸困难**等其他症状。
#
# 医生会提供更专业的评估和治疗方案，不要自己随便吃安眠药。
#
# 希望这些建议能帮到你，祝你今晚能有个好梦！
#
# ==================================================
#
# 【第2轮对话】
# [Content(
#   parts=[
#     Part(
#       text='简单清晰的回答用户问题'
#     ),
#   ],
#   role='user'
# ), Content(
#   parts=[
#     Part(
#       text='我最近总失眠，怎么办？'
#     ),
#   ],
#   role='user'
# ), Content(
#   parts=[
#     Part(
#       text="""好的，非常理解你被失眠困扰的感受。失眠确实很痛苦。
#
# 这里为你整理了一些简单清晰、可以立刻开始尝试的方法，希望能帮到你。
#
# 你可以把这些方法看作一个“睡眠工具箱”，尝试几种，找到最适合你的组合。
#
# ### 一、 睡前准备（营造睡觉的“仪式感”）
#
# 1.  **放松身体**：睡前1-2小时，洗个热水澡、泡个脚，或者用温毛巾热敷一下眼睛和脖子，让身体暖和放松下来。
# 2.  **远离电子产品**：至少在睡前1小时，放下手机、电脑、电视。屏幕的蓝光会抑制褪黑素（帮助你入睡的激素）的分泌。可以改成看会儿纸质书、听听舒缓的音乐或播客。
# 3.  **创造舒适环境**：把卧室弄得**暗一点、安静一点、凉快一点**。可以使用遮光窗帘、耳塞或白噪音机。
# 4.  **别在床上干别的事**：床只用来睡觉和亲密行为。不要在床上工作、玩手机或吃饭，让你的大脑把“床”和“睡觉”牢牢绑定在一起。
#
# ### 二、 白天习惯（调整你的生物钟）
#
# 1.  **作息规律**：每天尽量在**同一时间睡觉，同一时间起床**，即使是周末也要坚持。这是最有效的方法之一。
# 2.  **白天多晒太阳**：早上起床后，拉开窗帘，晒15-30分钟太阳。这能帮你校准生物钟，让身体知道“现在是白天，该清醒了”。
# 3.  **规律运动**：白天进行适度的运动（比如散步、慢跑、瑜伽）非常有帮助，但**不要在睡前3小时内剧烈运动**，否则会让身体太兴奋。
# 4.  **注意饮食**：
#     *   **避免咖啡因和酒精**：下午之后尽量不喝咖啡、浓茶、可乐等含咖啡因的饮料。酒精虽然能让你很快睡着，但会严重破坏后半夜的睡眠质量。
#     *   **睡前别吃太饱或太饿**：晚餐别吃太晚。如果睡前饿了，可以喝一小杯温牛奶或吃一根香蕉。
#
# ### 三、 心态调整（别跟“睡不着”这件事较劲）
#
# 1.  **放下“必须睡着”的压力**：越是强迫自己入睡，就越焦虑，越睡不着。告诉自己，躺着休息也是好的。
# 2.  **如果睡不着就起来**：如果在床上躺了20-30分钟还是毫无睡意，不要干躺着。**起床**，去另一个房间做点放松的事（比如看看书、听听音乐），直到感觉困了再回到床上。
# 3.  **把烦恼写下来**：如果脑子里总是有各种烦心事，可以在睡前花10分钟，把它们写在一个本子上。这就像把烦恼“清空”出大脑，有助于平静下来。
#
# ---
#
# ### **重要提醒：什么时候该去看医生？**
#
# 如果出现以下情况，建议尽快咨询医生（可以去医院的**睡眠科**或**神经内科**）：
#
# *   **失眠持续超过一个月**，并且尝试了以上方法后没有改善。
# *   失眠已经**严重影响了你的日常生活、工作和情绪**（比如白天非常疲惫、注意力不集中、容易发脾气）。
# *   失眠的同时，还伴有**情绪低落、焦虑、呼吸困难**等其他症状。
#
# 医生会提供更专业的评估和治疗方案，不要自己随便吃安眠药。
#
# 希望这些建议能帮到你，祝你今晚能有个好梦！"""
#     ),
#   ],
#   role='model'
# ), Content(
#   parts=[
#     Part(
#       text='我通常12点左右上床'
#     ),
#   ],
#   role='user'
# )]
# 👤 用户：我通常12点左右上床
# 🤖 AI：好的，了解了。12点左右上床，这个信息很重要。
#
# **12点上床本身不是问题**，很多人都是这个作息。关键在于以下几点，你可以对照看看自己属于哪种情况：
#
# ### 先问自己几个问题：
#
# 1.  **起床时间规律吗？**
#     *   你是每天早上（包括周末）都在**固定时间**起床吗？比如都是7点半或8点。
#     *   还是工作日起得早，周末就睡到中午？（这会打乱生物钟，是失眠的常见原因）
#
# 2.  **能睡够7-8小时吗？**
#     *   如果你12点上床，早上7-8点起床，那么理论上睡眠时间是足够的。
#     *   但问题是，你从躺下到**真正睡着**需要多久？如果需要1-2个小时，那实际睡眠时间就不够了。
#
# 3.  **12点上床前，你在做什么？**
#     *   是不是一直玩手机、看视频或玩游戏到11点55分，然后马上关灯睡觉？
#     *   如果是这样，你的大脑还处在兴奋状态，很难立刻“关机”进入睡眠模式。
#
# ### 针对你情况的精准建议：
#
# 知道了你12点上床的习惯，我们可以把之前的建议变得更具体：
#
# **核心策略：固定“起床时间”，然后倒推你的“放松时间”。**
#
# 1.  **第一步：先固定起床时间 (这是最重要的！)**
#     *   无论你前一晚几点睡着，第二天都在**同一个时间**起床。比如，如果你规定自己早上7:30起床，那就严格执行，**周末也一样**。
#     *   这就像给你的生物钟一个强力校准信号，坚持一两周效果会很明显。
#
# 2.  **第二步：从12点开始倒推，建立“睡前一小时”的放松仪式。**
#     *   **23:00 - 23:50 (放松时间)**：放下所有电子产品！把这个时间段当作“睡眠准备期”。你可以：
#         *   泡个脚（15-20分钟）。
#         *   调暗灯光，看几页纸质书。
#         *   听一些舒缓的音乐或白噪音。
#         *   做一些简单的拉伸或冥想。
#     *   **23:50 (上床准备)**：去洗手间，喝一小口水，确保卧室环境是舒适的（暗、安静、凉爽）。
#     *   **00:00 (准时躺下)**：上床，只准备睡觉。
#
# 3.  **第三步：躺下后，别跟自己较劲。**
#     *   如果你12点躺下了，但到了12点半甚至1点还非常清醒，**不要在床上干躺着焦虑**。
#     *   果断起床，去客厅或书房，在昏暗的灯光下看会儿书，直到感觉困意来了，再回去睡觉。
#
# **总结一下：**
#
# 你的问题不在于“12点”这个时间点，而很可能在于**没有给大脑足够的缓冲时间**从白天的兴奋状态切换到睡眠状态。
#
# 试试看，从今天开始，**先定好明早的闹钟，然后从11点开始，给自己一个“无手机”的睡前放松小时**。
#
# 希望这个更具体的建议能帮到你！
#
# ==================================================
#
# 【第3轮对话】
# [Content(
#   parts=[
#     Part(
#       text='简单清晰的回答用户问题'
#     ),
#   ],
#   role='user'
# ), Content(
#   parts=[
#     Part(
#       text='我最近总失眠，怎么办？'
#     ),
#   ],
#   role='user'
# ), Content(
#   parts=[
#     Part(
#       text="""好的，非常理解你被失眠困扰的感受。失眠确实很痛苦。
#
# 这里为你整理了一些简单清晰、可以立刻开始尝试的方法，希望能帮到你。
#
# 你可以把这些方法看作一个“睡眠工具箱”，尝试几种，找到最适合你的组合。
#
# ### 一、 睡前准备（营造睡觉的“仪式感”）
#
# 1.  **放松身体**：睡前1-2小时，洗个热水澡、泡个脚，或者用温毛巾热敷一下眼睛和脖子，让身体暖和放松下来。
# 2.  **远离电子产品**：至少在睡前1小时，放下手机、电脑、电视。屏幕的蓝光会抑制褪黑素（帮助你入睡的激素）的分泌。可以改成看会儿纸质书、听听舒缓的音乐或播客。
# 3.  **创造舒适环境**：把卧室弄得**暗一点、安静一点、凉快一点**。可以使用遮光窗帘、耳塞或白噪音机。
# 4.  **别在床上干别的事**：床只用来睡觉和亲密行为。不要在床上工作、玩手机或吃饭，让你的大脑把“床”和“睡觉”牢牢绑定在一起。
#
# ### 二、 白天习惯（调整你的生物钟）
#
# 1.  **作息规律**：每天尽量在**同一时间睡觉，同一时间起床**，即使是周末也要坚持。这是最有效的方法之一。
# 2.  **白天多晒太阳**：早上起床后，拉开窗帘，晒15-30分钟太阳。这能帮你校准生物钟，让身体知道“现在是白天，该清醒了”。
# 3.  **规律运动**：白天进行适度的运动（比如散步、慢跑、瑜伽）非常有帮助，但**不要在睡前3小时内剧烈运动**，否则会让身体太兴奋。
# 4.  **注意饮食**：
#     *   **避免咖啡因和酒精**：下午之后尽量不喝咖啡、浓茶、可乐等含咖啡因的饮料。酒精虽然能让你很快睡着，但会严重破坏后半夜的睡眠质量。
#     *   **睡前别吃太饱或太饿**：晚餐别吃太晚。如果睡前饿了，可以喝一小杯温牛奶或吃一根香蕉。
#
# ### 三、 心态调整（别跟“睡不着”这件事较劲）
#
# 1.  **放下“必须睡着”的压力**：越是强迫自己入睡，就越焦虑，越睡不着。告诉自己，躺着休息也是好的。
# 2.  **如果睡不着就起来**：如果在床上躺了20-30分钟还是毫无睡意，不要干躺着。**起床**，去另一个房间做点放松的事（比如看看书、听听音乐），直到感觉困了再回到床上。
# 3.  **把烦恼写下来**：如果脑子里总是有各种烦心事，可以在睡前花10分钟，把它们写在一个本子上。这就像把烦恼“清空”出大脑，有助于平静下来。
#
# ---
#
# ### **重要提醒：什么时候该去看医生？**
#
# 如果出现以下情况，建议尽快咨询医生（可以去医院的**睡眠科**或**神经内科**）：
#
# *   **失眠持续超过一个月**，并且尝试了以上方法后没有改善。
# *   失眠已经**严重影响了你的日常生活、工作和情绪**（比如白天非常疲惫、注意力不集中、容易发脾气）。
# *   失眠的同时，还伴有**情绪低落、焦虑、呼吸困难**等其他症状。
#
# 医生会提供更专业的评估和治疗方案，不要自己随便吃安眠药。
#
# 希望这些建议能帮到你，祝你今晚能有个好梦！"""
#     ),
#   ],
#   role='model'
# ), Content(
#   parts=[
#     Part(
#       text='我通常12点左右上床'
#     ),
#   ],
#   role='user'
# ), Content(
#   parts=[
#     Part(
#       text="""好的，了解了。12点左右上床，这个信息很重要。
#
# **12点上床本身不是问题**，很多人都是这个作息。关键在于以下几点，你可以对照看看自己属于哪种情况：
#
# ### 先问自己几个问题：
#
# 1.  **起床时间规律吗？**
#     *   你是每天早上（包括周末）都在**固定时间**起床吗？比如都是7点半或8点。
#     *   还是工作日起得早，周末就睡到中午？（这会打乱生物钟，是失眠的常见原因）
#
# 2.  **能睡够7-8小时吗？**
#     *   如果你12点上床，早上7-8点起床，那么理论上睡眠时间是足够的。
#     *   但问题是，你从躺下到**真正睡着**需要多久？如果需要1-2个小时，那实际睡眠时间就不够了。
#
# 3.  **12点上床前，你在做什么？**
#     *   是不是一直玩手机、看视频或玩游戏到11点55分，然后马上关灯睡觉？
#     *   如果是这样，你的大脑还处在兴奋状态，很难立刻“关机”进入睡眠模式。
#
# ### 针对你情况的精准建议：
#
# 知道了你12点上床的习惯，我们可以把之前的建议变得更具体：
#
# **核心策略：固定“起床时间”，然后倒推你的“放松时间”。**
#
# 1.  **第一步：先固定起床时间 (这是最重要的！)**
#     *   无论你前一晚几点睡着，第二天都在**同一个时间**起床。比如，如果你规定自己早上7:30起床，那就严格执行，**周末也一样**。
#     *   这就像给你的生物钟一个强力校准信号，坚持一两周效果会很明显。
#
# 2.  **第二步：从12点开始倒推，建立“睡前一小时”的放松仪式。**
#     *   **23:00 - 23:50 (放松时间)**：放下所有电子产品！把这个时间段当作“睡眠准备期”。你可以：
#         *   泡个脚（15-20分钟）。
#         *   调暗灯光，看几页纸质书。
#         *   听一些舒缓的音乐或白噪音。
#         *   做一些简单的拉伸或冥想。
#     *   **23:50 (上床准备)**：去洗手间，喝一小口水，确保卧室环境是舒适的（暗、安静、凉爽）。
#     *   **00:00 (准时躺下)**：上床，只准备睡觉。
#
# 3.  **第三步：躺下后，别跟自己较劲。**
#     *   如果你12点躺下了，但到了12点半甚至1点还非常清醒，**不要在床上干躺着焦虑**。
#     *   果断起床，去客厅或书房，在昏暗的灯光下看会儿书，直到感觉困意来了，再回去睡觉。
#
# **总结一下：**
#
# 你的问题不在于“12点”这个时间点，而很可能在于**没有给大脑足够的缓冲时间**从白天的兴奋状态切换到睡眠状态。
#
# 试试看，从今天开始，**先定好明早的闹钟，然后从11点开始，给自己一个“无手机”的睡前放松小时**。
#
# 希望这个更具体的建议能帮到你！"""
#     ),
#   ],
#   role='model'
# ), Content(
#   parts=[
#     Part(
#       text='入睡需要至少1小时'
#     ),
#   ],
#   role='user'
# )]
# 👤 用户：入睡需要至少1小时
# 🤖 AI：好的，收到了这个非常具体的信息——“入睡需要至少1小时”。
#
# 这非常典型，也是失眠最折磨人的地方之一。这种情况在医学上叫做“**入睡困难**”（Sleep-onset Insomnia）。
#
# 简单来说，就是**你的身体已经躺下了，但你的大脑还在“高速运转”，拒绝关机**。
#
# 这背后的原因通常是两个：
#
# 1.  **生理上过度兴奋**：睡前接触了蓝光（手机）、咖啡因，或者进行了剧烈运动。
# 2.  **心理上过度焦虑**：脑子里反复想事情，或者因为担心“今晚又睡不着”而产生焦虑，结果越焦虑越清醒，形成恶性循环。
#
# 针对你“入睡需要1小时”这个问题，这里有一些更精准的、专门用来“给大脑降速”的方法。
#
# ### 精准对策：如何让“高速运转的大脑”平静下来
#
# #### 1. “清空大脑”的技巧（睡前或睡不着时用）
#
# *   **执行“烦恼十五分钟”**：
#     *   在睡前1-2小时，找个本子和笔。
#     *   花15分钟，把你脑子里所有担心的事、明天要做的事、任何让你焦虑的想法，**全部写下来**。
#     *   在旁边简单写下“明天上午10点再想”或者“解决方案是XXX”。
#     *   这个过程就像把大脑里的“垃圾”倒出来，合上本子，告诉自己：“好了，今天的大脑工作到此结束。”
#
# *   **练习4-7-8呼吸法（最有效的快速放松技巧之一）**：
#     *   这个方法可以直接在床上做，能强制性地让你的神经系统从“紧张模式”切换到“放松模式”。
#     *   **准备**：用舌尖抵住上颚（上门牙后面一点）。
#     *   **第一步**：用鼻子**深深吸气**，心里默数**4秒**。
#     *   **第二步**：**屏住呼吸**，心里默数**7秒**。
#     *   **第三步**：用嘴巴**缓缓呼气**，发出“嘶……”的声音，心里默数**8秒**。
#     *   重复3-5次。你会感觉到心率明显慢下来，身体也沉下来了。
#
# #### 2. 优化你的“睡前流程”
#
# *   **把“放松时间”提前并加长**：
#     *   既然你12点上床，1点才能睡着，说明11点开始放松可能不够。
#     *   **试着从10:30就开始“断电”**。给自己一个半小时的缓冲期。这段时间里，把灯光调暗，做一些“无聊”但放松的事，比如：
#         *   **看一本稍微有点枯燥的纸质书**。（太精彩的小说反而会让你兴奋）
#         *   **听一些平缓的纯音乐、白噪音**（如下雨声、海浪声）。
#         *   **做温和的拉伸**，放松肩膀、脖子和后背。
#
# #### 3. 改变在床上的行为（这是关键！）
#
# *   **严格执行“20分钟原则”**：
#     *   这是对抗“入睡困难”的黄金法则。
#     *   如果你躺在床上**超过20分钟**，感觉自己非常清醒，毫无睡意，甚至开始烦躁。
#     *   **请立刻起床！**
#     *   去另一个房间（比如客厅），在昏暗的灯光下，做点放松的事情（比如看书、听音乐），**直到你明确感到困了**，再回到床上。
#     *   这个原则的目的是：**打破“床 = 睡不着、焦虑”的条件反射**。你必须让你的大脑重新相信：床，就是用来睡觉的，不是用来清醒地躺着受罪的。
#
# ### 总结一下给你最核心的建议：
#
# 1.  **睡前练习“烦恼十五分钟”+“4-7-8呼吸法”**，主动给大脑减速。
# 2.  **把无电子产品的放松时间从1小时延长到1.5小时**（10:30开始）。
# 3.  **躺下后如果20分钟没睡着，果断起床**，等困了再回去。
#
# 你不是一个人在战斗，很多人都有同样的问题，这完全可以改善。请不要因为睡不着而自责，把它当成一个需要解决的“小项目”，用这些方法去“调试”一下你的睡眠系统。
#
# 祝你今晚能更快地进入梦乡。
#
# ==================================================
#
# 【第4轮对话】
# [Content(
#   parts=[
#     Part(
#       text='简单清晰的回答用户问题'
#     ),
#   ],
#   role='user'
# ), Content(
#   parts=[
#     Part(
#       text='我最近总失眠，怎么办？'
#     ),
#   ],
#   role='user'
# ), Content(
#   parts=[
#     Part(
#       text="""好的，非常理解你被失眠困扰的感受。失眠确实很痛苦。
#
# 这里为你整理了一些简单清晰、可以立刻开始尝试的方法，希望能帮到你。
#
# 你可以把这些方法看作一个“睡眠工具箱”，尝试几种，找到最适合你的组合。
#
# ### 一、 睡前准备（营造睡觉的“仪式感”）
#
# 1.  **放松身体**：睡前1-2小时，洗个热水澡、泡个脚，或者用温毛巾热敷一下眼睛和脖子，让身体暖和放松下来。
# 2.  **远离电子产品**：至少在睡前1小时，放下手机、电脑、电视。屏幕的蓝光会抑制褪黑素（帮助你入睡的激素）的分泌。可以改成看会儿纸质书、听听舒缓的音乐或播客。
# 3.  **创造舒适环境**：把卧室弄得**暗一点、安静一点、凉快一点**。可以使用遮光窗帘、耳塞或白噪音机。
# 4.  **别在床上干别的事**：床只用来睡觉和亲密行为。不要在床上工作、玩手机或吃饭，让你的大脑把“床”和“睡觉”牢牢绑定在一起。
#
# ### 二、 白天习惯（调整你的生物钟）
#
# 1.  **作息规律**：每天尽量在**同一时间睡觉，同一时间起床**，即使是周末也要坚持。这是最有效的方法之一。
# 2.  **白天多晒太阳**：早上起床后，拉开窗帘，晒15-30分钟太阳。这能帮你校准生物钟，让身体知道“现在是白天，该清醒了”。
# 3.  **规律运动**：白天进行适度的运动（比如散步、慢跑、瑜伽）非常有帮助，但**不要在睡前3小时内剧烈运动**，否则会让身体太兴奋。
# 4.  **注意饮食**：
#     *   **避免咖啡因和酒精**：下午之后尽量不喝咖啡、浓茶、可乐等含咖啡因的饮料。酒精虽然能让你很快睡着，但会严重破坏后半夜的睡眠质量。
#     *   **睡前别吃太饱或太饿**：晚餐别吃太晚。如果睡前饿了，可以喝一小杯温牛奶或吃一根香蕉。
#
# ### 三、 心态调整（别跟“睡不着”这件事较劲）
#
# 1.  **放下“必须睡着”的压力**：越是强迫自己入睡，就越焦虑，越睡不着。告诉自己，躺着休息也是好的。
# 2.  **如果睡不着就起来**：如果在床上躺了20-30分钟还是毫无睡意，不要干躺着。**起床**，去另一个房间做点放松的事（比如看看书、听听音乐），直到感觉困了再回到床上。
# 3.  **把烦恼写下来**：如果脑子里总是有各种烦心事，可以在睡前花10分钟，把它们写在一个本子上。这就像把烦恼“清空”出大脑，有助于平静下来。
#
# ---
#
# ### **重要提醒：什么时候该去看医生？**
#
# 如果出现以下情况，建议尽快咨询医生（可以去医院的**睡眠科**或**神经内科**）：
#
# *   **失眠持续超过一个月**，并且尝试了以上方法后没有改善。
# *   失眠已经**严重影响了你的日常生活、工作和情绪**（比如白天非常疲惫、注意力不集中、容易发脾气）。
# *   失眠的同时，还伴有**情绪低落、焦虑、呼吸困难**等其他症状。
#
# 医生会提供更专业的评估和治疗方案，不要自己随便吃安眠药。
#
# 希望这些建议能帮到你，祝你今晚能有个好梦！"""
#     ),
#   ],
#   role='model'
# ), Content(
#   parts=[
#     Part(
#       text='我通常12点左右上床'
#     ),
#   ],
#   role='user'
# ), Content(
#   parts=[
#     Part(
#       text="""好的，了解了。12点左右上床，这个信息很重要。
#
# **12点上床本身不是问题**，很多人都是这个作息。关键在于以下几点，你可以对照看看自己属于哪种情况：
#
# ### 先问自己几个问题：
#
# 1.  **起床时间规律吗？**
#     *   你是每天早上（包括周末）都在**固定时间**起床吗？比如都是7点半或8点。
#     *   还是工作日起得早，周末就睡到中午？（这会打乱生物钟，是失眠的常见原因）
#
# 2.  **能睡够7-8小时吗？**
#     *   如果你12点上床，早上7-8点起床，那么理论上睡眠时间是足够的。
#     *   但问题是，你从躺下到**真正睡着**需要多久？如果需要1-2个小时，那实际睡眠时间就不够了。
#
# 3.  **12点上床前，你在做什么？**
#     *   是不是一直玩手机、看视频或玩游戏到11点55分，然后马上关灯睡觉？
#     *   如果是这样，你的大脑还处在兴奋状态，很难立刻“关机”进入睡眠模式。
#
# ### 针对你情况的精准建议：
#
# 知道了你12点上床的习惯，我们可以把之前的建议变得更具体：
#
# **核心策略：固定“起床时间”，然后倒推你的“放松时间”。**
#
# 1.  **第一步：先固定起床时间 (这是最重要的！)**
#     *   无论你前一晚几点睡着，第二天都在**同一个时间**起床。比如，如果你规定自己早上7:30起床，那就严格执行，**周末也一样**。
#     *   这就像给你的生物钟一个强力校准信号，坚持一两周效果会很明显。
#
# 2.  **第二步：从12点开始倒推，建立“睡前一小时”的放松仪式。**
#     *   **23:00 - 23:50 (放松时间)**：放下所有电子产品！把这个时间段当作“睡眠准备期”。你可以：
#         *   泡个脚（15-20分钟）。
#         *   调暗灯光，看几页纸质书。
#         *   听一些舒缓的音乐或白噪音。
#         *   做一些简单的拉伸或冥想。
#     *   **23:50 (上床准备)**：去洗手间，喝一小口水，确保卧室环境是舒适的（暗、安静、凉爽）。
#     *   **00:00 (准时躺下)**：上床，只准备睡觉。
#
# 3.  **第三步：躺下后，别跟自己较劲。**
#     *   如果你12点躺下了，但到了12点半甚至1点还非常清醒，**不要在床上干躺着焦虑**。
#     *   果断起床，去客厅或书房，在昏暗的灯光下看会儿书，直到感觉困意来了，再回去睡觉。
#
# **总结一下：**
#
# 你的问题不在于“12点”这个时间点，而很可能在于**没有给大脑足够的缓冲时间**从白天的兴奋状态切换到睡眠状态。
#
# 试试看，从今天开始，**先定好明早的闹钟，然后从11点开始，给自己一个“无手机”的睡前放松小时**。
#
# 希望这个更具体的建议能帮到你！"""
#     ),
#   ],
#   role='model'
# ), Content(
#   parts=[
#     Part(
#       text='入睡需要至少1小时'
#     ),
#   ],
#   role='user'
# ), Content(
#   parts=[
#     Part(
#       text="""好的，收到了这个非常具体的信息——“入睡需要至少1小时”。
#
# 这非常典型，也是失眠最折磨人的地方之一。这种情况在医学上叫做“**入睡困难**”（Sleep-onset Insomnia）。
#
# 简单来说，就是**你的身体已经躺下了，但你的大脑还在“高速运转”，拒绝关机**。
#
# 这背后的原因通常是两个：
#
# 1.  **生理上过度兴奋**：睡前接触了蓝光（手机）、咖啡因，或者进行了剧烈运动。
# 2.  **心理上过度焦虑**：脑子里反复想事情，或者因为担心“今晚又睡不着”而产生焦虑，结果越焦虑越清醒，形成恶性循环。
#
# 针对你“入睡需要1小时”这个问题，这里有一些更精准的、专门用来“给大脑降速”的方法。
#
# ### 精准对策：如何让“高速运转的大脑”平静下来
#
# #### 1. “清空大脑”的技巧（睡前或睡不着时用）
#
# *   **执行“烦恼十五分钟”**：
#     *   在睡前1-2小时，找个本子和笔。
#     *   花15分钟，把你脑子里所有担心的事、明天要做的事、任何让你焦虑的想法，**全部写下来**。
#     *   在旁边简单写下“明天上午10点再想”或者“解决方案是XXX”。
#     *   这个过程就像把大脑里的“垃圾”倒出来，合上本子，告诉自己：“好了，今天的大脑工作到此结束。”
#
# *   **练习4-7-8呼吸法（最有效的快速放松技巧之一）**：
#     *   这个方法可以直接在床上做，能强制性地让你的神经系统从“紧张模式”切换到“放松模式”。
#     *   **准备**：用舌尖抵住上颚（上门牙后面一点）。
#     *   **第一步**：用鼻子**深深吸气**，心里默数**4秒**。
#     *   **第二步**：**屏住呼吸**，心里默数**7秒**。
#     *   **第三步**：用嘴巴**缓缓呼气**，发出“嘶……”的声音，心里默数**8秒**。
#     *   重复3-5次。你会感觉到心率明显慢下来，身体也沉下来了。
#
# #### 2. 优化你的“睡前流程”
#
# *   **把“放松时间”提前并加长**：
#     *   既然你12点上床，1点才能睡着，说明11点开始放松可能不够。
#     *   **试着从10:30就开始“断电”**。给自己一个半小时的缓冲期。这段时间里，把灯光调暗，做一些“无聊”但放松的事，比如：
#         *   **看一本稍微有点枯燥的纸质书**。（太精彩的小说反而会让你兴奋）
#         *   **听一些平缓的纯音乐、白噪音**（如下雨声、海浪声）。
#         *   **做温和的拉伸**，放松肩膀、脖子和后背。
#
# #### 3. 改变在床上的行为（这是关键！）
#
# *   **严格执行“20分钟原则”**：
#     *   这是对抗“入睡困难”的黄金法则。
#     *   如果你躺在床上**超过20分钟**，感觉自己非常清醒，毫无睡意，甚至开始烦躁。
#     *   **请立刻起床！**
#     *   去另一个房间（比如客厅），在昏暗的灯光下，做点放松的事情（比如看书、听音乐），**直到你明确感到困了**，再回到床上。
#     *   这个原则的目的是：**打破“床 = 睡不着、焦虑”的条件反射**。你必须让你的大脑重新相信：床，就是用来睡觉的，不是用来清醒地躺着受罪的。
#
# ### 总结一下给你最核心的建议：
#
# 1.  **睡前练习“烦恼十五分钟”+“4-7-8呼吸法”**，主动给大脑减速。
# 2.  **把无电子产品的放松时间从1小时延长到1.5小时**（10:30开始）。
# 3.  **躺下后如果20分钟没睡着，果断起床**，等困了再回去。
#
# 你不是一个人在战斗，很多人都有同样的问题，这完全可以改善。请不要因为睡不着而自责，把它当成一个需要解决的“小项目”，用这些方法去“调试”一下你的睡眠系统。
#
# 祝你今晚能更快地进入梦乡。"""
#     ),
#   ],
#   role='model'
# ), Content(
#   parts=[
#     Part(
#       text='工作压力确实挺大的'
#     ),
#   ],
#   role='user'
# )]
# 👤 用户：工作压力确实挺大的
# 🤖 AI：这一下子就说到了失眠最核心的点上。**工作压力大是导致入睡困难的最常见原因之一。**
#
# 我非常理解你的感受。当大脑因为工作压力而处于“战备状态”时，它就像一台停不下来的引擎，即使你身体躺在床上，它还在高速运转，思考着白天的问题、担心着明天的任务。
#
# 这就形成了一个恶性循环：
# **压力大 → 大脑无法平静 → 入睡困难 → 睡眠不足 → 第二天更累、压力更大 → 晚上更难入睡**
#
# 所以，我们的核心目标就非常明确了：**在睡觉前，如何有效地让大脑与工作“断开连接”，从“工作模式”切换到“休息模式”。**
#
# 下面是一些专门针对**工作压力大**导致的失眠，非常有效的方法。你可以把它们看作是每天下班后的“精神卸妆”步骤。
#
# ### 睡前策略：建立工作与休息的“防火墙”
#
# 1.  **创造一个“工作终止仪式” (最重要的技巧)**
#     *   在决定结束一天工作的那个时间点（比如晚上8点或9点），做一个有仪式感的动作来告诉大脑：“今天的工作到此为止了。”
#     *   **具体做法**：
#         1.  花5分钟快速浏览一下明天最重要的3件事，**写在纸上或备忘录里**。
#         2.  然后，合上电脑，整理一下桌面。
#         3.  对自己说一句（或者在心里默念）：“**好了，今天的工作结束了。**”
#     *   这个简单的仪式感，能给你的大脑一个强烈的“下班”信号。
#
# 2.  **设立“数字宵禁”时间**
#     *   从睡前1.5-2小时开始（比如你12点上床，那就从10点或10点半开始），**停止查看任何与工作相关的信息**，包括工作微信群、邮件、钉钉等。
#     *   如果怕错过紧急事情，可以告诉同事或领导：“我晚上10点后休息，有急事请直接打电话。” 这样可以大大减少你的查阅焦虑。
#
# 3.  **把大脑“清空”在纸上**
#     *   这个就是我们之前提到的“烦恼日志”的升级版。
#     *   睡前如果脑子里还在反复盘算工作的事，**不要在脑子里跟它斗争**。
#     *   起床，拿个本子，把所有让你焦虑的工作内容**全部写下来**，想到什么写什么，不用管逻辑。写完后，把本子合上，放到一边。这个动作相当于把这些想法“物理上地”移出你的大脑。
#
# ### 白天策略：主动“释放”累积的压力
#
# 失眠不是晚上才发生的事，而是白天压力的延续。
#
# 1.  **利用“微休息”来喘口气**
#     *   工作期间，每隔1小时，强制自己离开工位5分钟。不要看手机，就站起来走动一下，看看窗外，或者做几个深呼吸。这能有效防止压力值一整天都在持续攀升。
#
# 2.  **把运动当成“情绪垃圾桶”**
#     *   下班后，进行20-30分钟能让你微微出汗的运动，比如快走、慢跑、跳操。
#     *   运动是释放压力激素（皮质醇）最有效的方式之一。你可以想象成是**把一天积攒的压力和烦躁，通过汗水“代谢”出去**。
#
# 3.  **练习“正念”或“冥想”（每天10分钟）**
#     *   这听起来有点玄，但它其实是**给大脑做的“力量训练”**，训练它“活在当下”，而不是被思绪牵着鼻子走。
#     *   可以下载一些App（比如潮汐、Calm、Headspace），跟着引导语练习。每天10分钟，坚持一周，你就会发现自己更容易从纷乱的思绪中抽离出来。
#
# **最后，请调整心态：**
#
# 工作压力大的时候，偶尔一两晚睡不好是**非常正常**的。请不要因此责备自己，或者强求自己必须“睡个好觉”。你越是放松，睡眠反而会悄悄回来。
#
# 记住，**你的目标不是“战胜”失眠，而是“接纳”压力的存在，并学会与它共处**。
#
# 从今晚开始，试试建立一个简单的“工作终止仪式”吧，这是最容易上手且效果最明显的一步。祝你今晚能有一个更平静的夜晚。
#
# ==================================================
#
# 【第5轮对话】
# [Content(
#   parts=[
#     Part(
#       text='简单清晰的回答用户问题'
#     ),
#   ],
#   role='user'
# ), Content(
#   parts=[
#     Part(
#       text='我最近总失眠，怎么办？'
#     ),
#   ],
#   role='user'
# ), Content(
#   parts=[
#     Part(
#       text="""好的，非常理解你被失眠困扰的感受。失眠确实很痛苦。
#
# 这里为你整理了一些简单清晰、可以立刻开始尝试的方法，希望能帮到你。
#
# 你可以把这些方法看作一个“睡眠工具箱”，尝试几种，找到最适合你的组合。
#
# ### 一、 睡前准备（营造睡觉的“仪式感”）
#
# 1.  **放松身体**：睡前1-2小时，洗个热水澡、泡个脚，或者用温毛巾热敷一下眼睛和脖子，让身体暖和放松下来。
# 2.  **远离电子产品**：至少在睡前1小时，放下手机、电脑、电视。屏幕的蓝光会抑制褪黑素（帮助你入睡的激素）的分泌。可以改成看会儿纸质书、听听舒缓的音乐或播客。
# 3.  **创造舒适环境**：把卧室弄得**暗一点、安静一点、凉快一点**。可以使用遮光窗帘、耳塞或白噪音机。
# 4.  **别在床上干别的事**：床只用来睡觉和亲密行为。不要在床上工作、玩手机或吃饭，让你的大脑把“床”和“睡觉”牢牢绑定在一起。
#
# ### 二、 白天习惯（调整你的生物钟）
#
# 1.  **作息规律**：每天尽量在**同一时间睡觉，同一时间起床**，即使是周末也要坚持。这是最有效的方法之一。
# 2.  **白天多晒太阳**：早上起床后，拉开窗帘，晒15-30分钟太阳。这能帮你校准生物钟，让身体知道“现在是白天，该清醒了”。
# 3.  **规律运动**：白天进行适度的运动（比如散步、慢跑、瑜伽）非常有帮助，但**不要在睡前3小时内剧烈运动**，否则会让身体太兴奋。
# 4.  **注意饮食**：
#     *   **避免咖啡因和酒精**：下午之后尽量不喝咖啡、浓茶、可乐等含咖啡因的饮料。酒精虽然能让你很快睡着，但会严重破坏后半夜的睡眠质量。
#     *   **睡前别吃太饱或太饿**：晚餐别吃太晚。如果睡前饿了，可以喝一小杯温牛奶或吃一根香蕉。
#
# ### 三、 心态调整（别跟“睡不着”这件事较劲）
#
# 1.  **放下“必须睡着”的压力**：越是强迫自己入睡，就越焦虑，越睡不着。告诉自己，躺着休息也是好的。
# 2.  **如果睡不着就起来**：如果在床上躺了20-30分钟还是毫无睡意，不要干躺着。**起床**，去另一个房间做点放松的事（比如看看书、听听音乐），直到感觉困了再回到床上。
# 3.  **把烦恼写下来**：如果脑子里总是有各种烦心事，可以在睡前花10分钟，把它们写在一个本子上。这就像把烦恼“清空”出大脑，有助于平静下来。
#
# ---
#
# ### **重要提醒：什么时候该去看医生？**
#
# 如果出现以下情况，建议尽快咨询医生（可以去医院的**睡眠科**或**神经内科**）：
#
# *   **失眠持续超过一个月**，并且尝试了以上方法后没有改善。
# *   失眠已经**严重影响了你的日常生活、工作和情绪**（比如白天非常疲惫、注意力不集中、容易发脾气）。
# *   失眠的同时，还伴有**情绪低落、焦虑、呼吸困难**等其他症状。
#
# 医生会提供更专业的评估和治疗方案，不要自己随便吃安眠药。
#
# 希望这些建议能帮到你，祝你今晚能有个好梦！"""
#     ),
#   ],
#   role='model'
# ), Content(
#   parts=[
#     Part(
#       text='我通常12点左右上床'
#     ),
#   ],
#   role='user'
# ), Content(
#   parts=[
#     Part(
#       text="""好的，了解了。12点左右上床，这个信息很重要。
#
# **12点上床本身不是问题**，很多人都是这个作息。关键在于以下几点，你可以对照看看自己属于哪种情况：
#
# ### 先问自己几个问题：
#
# 1.  **起床时间规律吗？**
#     *   你是每天早上（包括周末）都在**固定时间**起床吗？比如都是7点半或8点。
#     *   还是工作日起得早，周末就睡到中午？（这会打乱生物钟，是失眠的常见原因）
#
# 2.  **能睡够7-8小时吗？**
#     *   如果你12点上床，早上7-8点起床，那么理论上睡眠时间是足够的。
#     *   但问题是，你从躺下到**真正睡着**需要多久？如果需要1-2个小时，那实际睡眠时间就不够了。
#
# 3.  **12点上床前，你在做什么？**
#     *   是不是一直玩手机、看视频或玩游戏到11点55分，然后马上关灯睡觉？
#     *   如果是这样，你的大脑还处在兴奋状态，很难立刻“关机”进入睡眠模式。
#
# ### 针对你情况的精准建议：
#
# 知道了你12点上床的习惯，我们可以把之前的建议变得更具体：
#
# **核心策略：固定“起床时间”，然后倒推你的“放松时间”。**
#
# 1.  **第一步：先固定起床时间 (这是最重要的！)**
#     *   无论你前一晚几点睡着，第二天都在**同一个时间**起床。比如，如果你规定自己早上7:30起床，那就严格执行，**周末也一样**。
#     *   这就像给你的生物钟一个强力校准信号，坚持一两周效果会很明显。
#
# 2.  **第二步：从12点开始倒推，建立“睡前一小时”的放松仪式。**
#     *   **23:00 - 23:50 (放松时间)**：放下所有电子产品！把这个时间段当作“睡眠准备期”。你可以：
#         *   泡个脚（15-20分钟）。
#         *   调暗灯光，看几页纸质书。
#         *   听一些舒缓的音乐或白噪音。
#         *   做一些简单的拉伸或冥想。
#     *   **23:50 (上床准备)**：去洗手间，喝一小口水，确保卧室环境是舒适的（暗、安静、凉爽）。
#     *   **00:00 (准时躺下)**：上床，只准备睡觉。
#
# 3.  **第三步：躺下后，别跟自己较劲。**
#     *   如果你12点躺下了，但到了12点半甚至1点还非常清醒，**不要在床上干躺着焦虑**。
#     *   果断起床，去客厅或书房，在昏暗的灯光下看会儿书，直到感觉困意来了，再回去睡觉。
#
# **总结一下：**
#
# 你的问题不在于“12点”这个时间点，而很可能在于**没有给大脑足够的缓冲时间**从白天的兴奋状态切换到睡眠状态。
#
# 试试看，从今天开始，**先定好明早的闹钟，然后从11点开始，给自己一个“无手机”的睡前放松小时**。
#
# 希望这个更具体的建议能帮到你！"""
#     ),
#   ],
#   role='model'
# ), Content(
#   parts=[
#     Part(
#       text='入睡需要至少1小时'
#     ),
#   ],
#   role='user'
# ), Content(
#   parts=[
#     Part(
#       text="""好的，收到了这个非常具体的信息——“入睡需要至少1小时”。
#
# 这非常典型，也是失眠最折磨人的地方之一。这种情况在医学上叫做“**入睡困难**”（Sleep-onset Insomnia）。
#
# 简单来说，就是**你的身体已经躺下了，但你的大脑还在“高速运转”，拒绝关机**。
#
# 这背后的原因通常是两个：
#
# 1.  **生理上过度兴奋**：睡前接触了蓝光（手机）、咖啡因，或者进行了剧烈运动。
# 2.  **心理上过度焦虑**：脑子里反复想事情，或者因为担心“今晚又睡不着”而产生焦虑，结果越焦虑越清醒，形成恶性循环。
#
# 针对你“入睡需要1小时”这个问题，这里有一些更精准的、专门用来“给大脑降速”的方法。
#
# ### 精准对策：如何让“高速运转的大脑”平静下来
#
# #### 1. “清空大脑”的技巧（睡前或睡不着时用）
#
# *   **执行“烦恼十五分钟”**：
#     *   在睡前1-2小时，找个本子和笔。
#     *   花15分钟，把你脑子里所有担心的事、明天要做的事、任何让你焦虑的想法，**全部写下来**。
#     *   在旁边简单写下“明天上午10点再想”或者“解决方案是XXX”。
#     *   这个过程就像把大脑里的“垃圾”倒出来，合上本子，告诉自己：“好了，今天的大脑工作到此结束。”
#
# *   **练习4-7-8呼吸法（最有效的快速放松技巧之一）**：
#     *   这个方法可以直接在床上做，能强制性地让你的神经系统从“紧张模式”切换到“放松模式”。
#     *   **准备**：用舌尖抵住上颚（上门牙后面一点）。
#     *   **第一步**：用鼻子**深深吸气**，心里默数**4秒**。
#     *   **第二步**：**屏住呼吸**，心里默数**7秒**。
#     *   **第三步**：用嘴巴**缓缓呼气**，发出“嘶……”的声音，心里默数**8秒**。
#     *   重复3-5次。你会感觉到心率明显慢下来，身体也沉下来了。
#
# #### 2. 优化你的“睡前流程”
#
# *   **把“放松时间”提前并加长**：
#     *   既然你12点上床，1点才能睡着，说明11点开始放松可能不够。
#     *   **试着从10:30就开始“断电”**。给自己一个半小时的缓冲期。这段时间里，把灯光调暗，做一些“无聊”但放松的事，比如：
#         *   **看一本稍微有点枯燥的纸质书**。（太精彩的小说反而会让你兴奋）
#         *   **听一些平缓的纯音乐、白噪音**（如下雨声、海浪声）。
#         *   **做温和的拉伸**，放松肩膀、脖子和后背。
#
# #### 3. 改变在床上的行为（这是关键！）
#
# *   **严格执行“20分钟原则”**：
#     *   这是对抗“入睡困难”的黄金法则。
#     *   如果你躺在床上**超过20分钟**，感觉自己非常清醒，毫无睡意，甚至开始烦躁。
#     *   **请立刻起床！**
#     *   去另一个房间（比如客厅），在昏暗的灯光下，做点放松的事情（比如看书、听音乐），**直到你明确感到困了**，再回到床上。
#     *   这个原则的目的是：**打破“床 = 睡不着、焦虑”的条件反射**。你必须让你的大脑重新相信：床，就是用来睡觉的，不是用来清醒地躺着受罪的。
#
# ### 总结一下给你最核心的建议：
#
# 1.  **睡前练习“烦恼十五分钟”+“4-7-8呼吸法”**，主动给大脑减速。
# 2.  **把无电子产品的放松时间从1小时延长到1.5小时**（10:30开始）。
# 3.  **躺下后如果20分钟没睡着，果断起床**，等困了再回去。
#
# 你不是一个人在战斗，很多人都有同样的问题，这完全可以改善。请不要因为睡不着而自责，把它当成一个需要解决的“小项目”，用这些方法去“调试”一下你的睡眠系统。
#
# 祝你今晚能更快地进入梦乡。"""
#     ),
#   ],
#   role='model'
# ), Content(
#   parts=[
#     Part(
#       text='工作压力确实挺大的'
#     ),
#   ],
#   role='user'
# ), Content(
#   parts=[
#     Part(
#       text="""这一下子就说到了失眠最核心的点上。**工作压力大是导致入睡困难的最常见原因之一。**
#
# 我非常理解你的感受。当大脑因为工作压力而处于“战备状态”时，它就像一台停不下来的引擎，即使你身体躺在床上，它还在高速运转，思考着白天的问题、担心着明天的任务。
#
# 这就形成了一个恶性循环：
# **压力大 → 大脑无法平静 → 入睡困难 → 睡眠不足 → 第二天更累、压力更大 → 晚上更难入睡**
#
# 所以，我们的核心目标就非常明确了：**在睡觉前，如何有效地让大脑与工作“断开连接”，从“工作模式”切换到“休息模式”。**
#
# 下面是一些专门针对**工作压力大**导致的失眠，非常有效的方法。你可以把它们看作是每天下班后的“精神卸妆”步骤。
#
# ### 睡前策略：建立工作与休息的“防火墙”
#
# 1.  **创造一个“工作终止仪式” (最重要的技巧)**
#     *   在决定结束一天工作的那个时间点（比如晚上8点或9点），做一个有仪式感的动作来告诉大脑：“今天的工作到此为止了。”
#     *   **具体做法**：
#         1.  花5分钟快速浏览一下明天最重要的3件事，**写在纸上或备忘录里**。
#         2.  然后，合上电脑，整理一下桌面。
#         3.  对自己说一句（或者在心里默念）：“**好了，今天的工作结束了。**”
#     *   这个简单的仪式感，能给你的大脑一个强烈的“下班”信号。
#
# 2.  **设立“数字宵禁”时间**
#     *   从睡前1.5-2小时开始（比如你12点上床，那就从10点或10点半开始），**停止查看任何与工作相关的信息**，包括工作微信群、邮件、钉钉等。
#     *   如果怕错过紧急事情，可以告诉同事或领导：“我晚上10点后休息，有急事请直接打电话。” 这样可以大大减少你的查阅焦虑。
#
# 3.  **把大脑“清空”在纸上**
#     *   这个就是我们之前提到的“烦恼日志”的升级版。
#     *   睡前如果脑子里还在反复盘算工作的事，**不要在脑子里跟它斗争**。
#     *   起床，拿个本子，把所有让你焦虑的工作内容**全部写下来**，想到什么写什么，不用管逻辑。写完后，把本子合上，放到一边。这个动作相当于把这些想法“物理上地”移出你的大脑。
#
# ### 白天策略：主动“释放”累积的压力
#
# 失眠不是晚上才发生的事，而是白天压力的延续。
#
# 1.  **利用“微休息”来喘口气**
#     *   工作期间，每隔1小时，强制自己离开工位5分钟。不要看手机，就站起来走动一下，看看窗外，或者做几个深呼吸。这能有效防止压力值一整天都在持续攀升。
#
# 2.  **把运动当成“情绪垃圾桶”**
#     *   下班后，进行20-30分钟能让你微微出汗的运动，比如快走、慢跑、跳操。
#     *   运动是释放压力激素（皮质醇）最有效的方式之一。你可以想象成是**把一天积攒的压力和烦躁，通过汗水“代谢”出去**。
#
# 3.  **练习“正念”或“冥想”（每天10分钟）**
#     *   这听起来有点玄，但它其实是**给大脑做的“力量训练”**，训练它“活在当下”，而不是被思绪牵着鼻子走。
#     *   可以下载一些App（比如潮汐、Calm、Headspace），跟着引导语练习。每天10分钟，坚持一周，你就会发现自己更容易从纷乱的思绪中抽离出来。
#
# **最后，请调整心态：**
#
# 工作压力大的时候，偶尔一两晚睡不好是**非常正常**的。请不要因此责备自己，或者强求自己必须“睡个好觉”。你越是放松，睡眠反而会悄悄回来。
#
# 记住，**你的目标不是“战胜”失眠，而是“接纳”压力的存在，并学会与它共处**。
#
# 从今晚开始，试试建立一个简单的“工作终止仪式”吧，这是最容易上手且效果最明显的一步。祝你今晚能有一个更平静的夜晚。"""
#     ),
#   ],
#   role='model'
# ), Content(
#   parts=[
#     Part(
#       text='有什么具体的改善建议吗？'
#     ),
#   ],
#   role='user'
# )]
# 👤 用户：有什么具体的改善建议吗？
# 🤖 AI：当然！我们把之前讨论的所有内容，整合成一个清晰、具体、可操作的**“三步改善计划”**。
#
# 你可以把它当作一份“睡眠改善说明书”，从今天开始就可以照着做。
#
# ---
#
# ### **“告别失眠”三步改善计划**
#
# 这个计划的核心是：**白天释放压力，睡前切换模式，睡中停止内耗。**
#
# #### **第一步：白天 & 下班后【主动释放压力】**
#
# 压力是水库，白天不泄洪，晚上就会决堤。
#
# 1.  **进行一次“排压运动”**：
#     *   **具体做法**：下班后，进行至少 **20-30分钟** 的运动，让自己微微出汗。快走、慢跑、游泳、跳操都可以。
#     *   **目的**：把一天积累的紧张情绪和压力激素，通过身体活动“代谢”掉。这是最直接、最有效的减压方式。
#     *   **注意**：请在睡前3小时完成，比如你12点上床，那就在晚上9点前完成运动。
#
# 2.  **设定一个“工作终止仪式”**：
#     *   **具体做法**：在结束一天工作时，花5分钟：
#         *   ① **写下**明天要做的最重要的3件事。
#         *   ② **合上电脑**，整理好桌面。
#         *   ③ **对自己说**：“今天的工作结束了。”
#     *   **目的**：给大脑一个强烈的“下班”信号，防止工作思绪蔓延到休息时间。
#
# #### **第二步：睡前1-2小时【强制切换到休息模式】**
#
# 这是从清醒到睡眠的“缓冲区”，至关重要。假设你12点上床，那就从10:30开始。
#
# 3.  **执行“数字宵禁”和“烦恼清空”**：
#     *   **具体做法**：
#         *   **10:30 PM**：把手机、平板等所有电子设备调成静音，放到客厅去充电，**不要带进卧室**。
#         *   **10:30 - 10:45 PM**：准备一个本子，把脑子里所有让你焦虑、烦心的工作和琐事**全部写下来**。写完，合上本子，就当把它们“寄存”在这里了。
#     *   **目的**：物理上切断干扰源，心理上“清空”大脑缓存。
#
# 4.  **进行一项“纯放松活动”**：
#     *   **具体做法**：在接下来的时间里（10:45 PM - 12:00 AM），做一件**与工作和手机完全无关**的放松事情。
#         *   **最佳推荐**：用温热水泡脚20分钟（可以加点精油）、听舒缓的纯音乐或播客、看几页“无聊”的纸质书、做一些简单的身体拉伸。
#     *   **目的**：让身体和大脑的转速都慢慢降下来。
#
# #### **第三步：上床后 & 夜里【停止与失眠“搏斗”】**
#
# 上床后的目标不是“睡着”，而是“放松”。
#
# 5.  **练习“4-7-8呼吸法”**：
#     *   **具体做法**：躺下后，如果感觉大脑还在想事情，做3-5组“4-7-8呼吸”：**用鼻子吸气4秒，憋气7秒，用嘴巴慢慢呼气8秒**。
#     *   **目的**：这是一个生理技巧，能快速降低心率，让身体进入放松状态。
#
# 6.  **严格遵守“20分钟原则”**：
#     *   **具体做法**：如果在床上躺了20分钟（大概感觉），还是非常清醒，甚至开始有点烦躁。**请立即起床**。
#     *   **去另一个房间**（比如客厅沙发），在昏暗的灯光下看会儿书或发发呆，**直到你感到明显的困意**，再回到床上。如果又睡不着，就再重复这个过程。
#     *   **目的**：打破“床 = 睡不着的地方”这个负面条件反射。这是整个计划中最关键，也是最需要意志力的一步，但效果最好。
#
# ---
#
# **总结一下，今晚你就可以开始的行动清单：**
#
# *   **① 下班后**：先去快走或慢跑半小时。
# *   **② 10:30后**：手机扔客厅，把烦心事写在本上，然后去泡个脚。
# *   **③ 12:00躺下后**：如果20分钟还没睡意，果断离开床，去客厅坐着，等困了再回去。
#
# 坚持一周，即使只是部分执行，相信你也能感觉到明显的变化。祝你成功！
#
# ✅ AI记住了所有信息：
#    - 失眠问题
#    - 12点上床
#    - 入睡需要1小时
#    - 工作压力大
#    - 给出了针对性的建议

# %% [markdown]
# ## 5️⃣ 查看对话历史
#
# Chat Session自动保存了所有对话

# %%
print(f"📚 对话历史中有 {len(chat_history)} 条消息\n")

for i, message in enumerate(chat_history):
    role = "👤 用户" if message.role == "user" else "🤖 AI"
    content = message.parts[0].text
    # 只显示前50个字符
    preview = content[:50] + "..." if len(content) > 50 else content
    print(f"{i+1}. {role}: {preview}")
# Out:
# 📚 对话历史中有 11 条消息
#
# 1. 👤 用户: 简单清晰的回答用户问题
# 2. 👤 用户: 我最近总失眠，怎么办？
# 3. 🤖 AI: 好的，非常理解你被失眠困扰的感受。失眠确实很痛苦。
#
# 这里为你整理了一些简单清晰、可以立刻开始尝试的...
# 4. 👤 用户: 我通常12点左右上床
# 5. 🤖 AI: 好的，了解了。12点左右上床，这个信息很重要。
#
# **12点上床本身不是问题**，很多人都是这个作息...
# 6. 👤 用户: 入睡需要至少1小时
# 7. 🤖 AI: 好的，收到了这个非常具体的信息——“入睡需要至少1小时”。
#
# 这非常典型，也是失眠最折磨人的地方之一...
# 8. 👤 用户: 工作压力确实挺大的
# 9. 🤖 AI: 这一下子就说到了失眠最核心的点上。**工作压力大是导致入睡困难的最常见原因之一。**
#
# 我非常理解你...
# 10. 👤 用户: 有什么具体的改善建议吗？
# 11. 🤖 AI: 当然！我们把之前讨论的所有内容，整合成一个清晰、具体、可操作的**“三步改善计划”**。
#
# 你可以把...

# %% [markdown]
# ## 6️⃣ 示例2：带有用户健康背景的对话
#
# 可以在创建Chat时注入用户的健康档案作为系统上下文

# %%
# 小明的健康档案（来自前面模块的数据）
user_profile = """
用户档案：
- 姓名：小明
- 年龄：28岁
- 职业：互联网产品经理
- 健康目标：每天睡足8小时，每周运动150分钟
- 最近一周数据：
  * 平均睡眠：7.3小时（低于目标）
  * 运动情况：周一跑步30分钟，周三瑜伽45分钟，周五游泳40分钟（共115分钟，低于目标）
  * 饮食：周四吃了快餐，其他几天饮食健康
  * 压力水平：周二和周四压力很高
"""

# 创建带有用户档案的Chat
chat_with_context = [
    types.Content(
        role="user",
        parts=[types.Part(text=f"我是小明，这是我的健康档案：{user_profile}\n请作为我的健康顾问，帮助我改善健康状况。")]
    ),
    types.Content(
        role="model",
        parts=[types.Part(text="你好小明！我已经了解了你的健康档案。我看到你最近一周的睡眠和运动都没有达到目标，而且有几天压力较大。我会作为你的健康顾问，帮助你逐步改善这些方面。有什么具体想咨询的吗？")]
    )
]

print("✅ 已创建带有用户健康档案的Chat Session\n")
print("="*50 + "\n")
# Out:
# ✅ 已创建带有用户健康档案的Chat Session
#
# ==================================================

# %% [markdown]
# ## 7️⃣ 基于档案的个性化对话
#
# AI会结合用户的健康档案给出针对性建议

# %%
# 对话1：询问睡眠改善
print("【对话1】")
response = send_message("怎么才能睡足8小时？", chat_with_context)
print("👤 小明：怎么才能睡足8小时？")
print(f"🤖 AI：{response.text}\n")
print("="*50 + "\n")

# 对话2：询问运动建议
print("【对话2】")
response = send_message("我还差35分钟运动时间，怎么补上？", chat_with_context)
print("👤 小明：我还差35分钟运动时间，怎么补上？")
print(f"🤖 AI：{response.text}\n")
print("="*50 + "\n")

# 对话3：压力管理
print("【对话3】")
response = send_message("工作压力大的时候应该怎么应对？", chat_with_context)
print("👤 小明：工作压力大的时候应该怎么应对？")
print(f"🤖 AI：{response.text}\n")

print("✅ 观察：AI的建议都基于小明的具体情况：")
print("   - 知道他的睡眠目标是8小时")
print("   - 知道他差35分钟才能达到运动目标")
print("   - 知道他周二和周四压力较大")

# %% [markdown]
# ## 8️⃣ 实现交互式健康顾问
#
# 创建一个可以持续对话的助手

# %%
def create_health_advisor(user_name="用户", user_info=""):
    """创建健康顾问Chat Session"""
    system_prompt = f"""你是一位专业的AI健康顾问，正在为{user_name}提供健康咨询服务。

角色定位：
- 专业：基于健康科学知识提供建议
- 关怀：理解用户的困难和挑战
- 责任：强调建议仅供参考，不替代专业医疗

{f'用户背景：{user_info}' if user_info else ''}

重要提醒：
⚠️ 始终强调你的建议仅供参考，严重健康问题需要就医
⚠️ 不做疾病诊断，只提供健康生活方式建议
"""

    chat_history = [
        types.Content(role="user", parts=[types.Part(text=system_prompt)]),
        types.Content(role="model", parts=[types.Part(text=f"你好{user_name}！我是你的AI健康顾问。我会基于健康科学知识为你提供建议，帮助你改善生活方式。需要提醒的是，我的建议仅供参考，严重健康问题请及时就医。有什么可以帮到你的吗？")])
    ]

    return chat_history

def chat_with_advisor(chat_history, max_turns=10):
    """与健康顾问进行对话"""
    print("💬 健康顾问对话（输入'退出'结束对话）\n")
    print("🤖 助手：你好！我是你的AI健康顾问，有什么可以帮到你的吗？\n")

    for turn in range(max_turns):
        user_input = input("👤 你：")

        if user_input.lower() in ['退出', 'quit', 'exit', 'q']:
            print("\n🤖 助手：再见！祝你健康！")
            break

        if not user_input.strip():
            continue

        response = send_message(user_input, chat_history)
        print(f"\n🤖 助手：{response.text}\n")

    print(f"\n📊 对话统计：共 {len(chat_history)} 条消息")

# 创建健康顾问
advisor_chat = create_health_advisor(
    user_name="小明",
    user_info=user_profile
)

print("✅ 健康顾问已创建！")
print("\n💡 提示：在实际使用时，取消下面代码的注释来进行交互式对话")
print("# chat_with_advisor(advisor_chat)")
# Out:
# ✅ 健康顾问已创建！
#
# 💡 提示：在实际使用时，取消下面代码的注释来进行交互式对话
# # chat_with_advisor(advisor_chat)
