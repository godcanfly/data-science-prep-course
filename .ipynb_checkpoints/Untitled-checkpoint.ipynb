# %%
print("Hello, Data Science!")
name = "Alice"
scores = [85, 90, 78, 92]
print(f"{name} is ready to learn!")
# Out:
# Hello, Data Science!
# Alice is ready to learn!

# %%
print("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %%
print("test "+ name + " good")
print(f" {name}   ")
print(f" {name}  {name}   ")
# Out:
# test Alice good
#  Alice
#  Alice  Alice

# %%
x = "sdjfjsjfds"
y = 10.1
z = [1,2,3,4]
z = [[1,2,3.4],[],3,4]
